# %%
from SPARQLWrapper import SPARQLWrapper, JSON
from rdflib import Graph

# %%
sparql = SPARQLWrapper("https://datos.gob.es/virtuoso/sparql")
sparql.setQuery("""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    select distinct ?x where
    {
    # ?x ?p ?o 
    FILTER  (regex(?x,"/Organismo/","i"))
    }

    LIMIT 100
""")

# %%
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results["results"]["bindings"]
# Out:
# [{'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L02000011'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0001301'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/A01002820'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01200697'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01280148'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/A08002880'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/A02002834'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/A04003003'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/A05003638'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/A07002862'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/A10002983'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/A12002994'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/A16003011'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/A17002943'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E00003301'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E00003801'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E00003901'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E00125901'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E00130201'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E00130302'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E04585801'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E04921401'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E04990201'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E04990301'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0001277'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0001302'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0001304'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0001306'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0001308'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0001314'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0001318'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0001320'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01100377'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01230601'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01280066'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01280796'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01281230'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01290672'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01300243'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01312016'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01330241'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01350167'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01390759'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01462444'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01462508'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01480209'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01502973'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L02000008'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L02000012'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L02000020'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L03380011'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/U00000046'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/U00200001'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01082114'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01080193'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/A14005495'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/U02100001'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01281343'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01110201'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/A14002961'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E00125801'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E00131802'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E00142603'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0001313'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E00142503'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E04926001'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01081017'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E00116401'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01380380'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0022266'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01150780'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01081120'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/A13002908'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E05024301'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/U02800001'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0020855'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0020886'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0020936'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0022425'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0022545'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0028449'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0040127'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0040767'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0020890'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0022323'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/I00000847'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0019807'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0022992'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/I00000121'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/EA0022045'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/U01000001'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E05072501'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01462021'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E05024201'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/I00000687'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/E05070101'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/U03400001'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01431482'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/A09002970'}},
#  {'x': {'type': 'uri',
#    'value': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01010590'}}]
